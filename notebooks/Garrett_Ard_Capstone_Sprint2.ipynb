# %% [markdown]
# Rough draft file; finalize in Jupyter Notebook - probably in my_env ✅

# %% [markdown]
# ---
# # <u>Data Dictionary</u>

# %% [markdown]
# *To assist with analysis, please see the data dictionary below.*
#
# #### <u><span style=color:orange>**Cab Ride</span> Data:**</u>

# %% [markdown]
# <table>
#   <tr>
#     <th style="text-align: left; background: lightgrey">Field Name</th>
#     <th style="text-align: left; background: lightgrey">Description</th>
#  </tr>
#   <tr>
#     <td style="text-align: left"> <code>DISTANCE</code> </td>
#     <td style="text-align: left">distance between Source and Destination, miles (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>CAB_TYPE</code></td>
#     <td style="text-align: left">Uber or Lyft (<strong>categorical</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>NAME</code></td>
#     <td style="text-align: left">cab service name (<strong>categorical</strong>); Note: 'WAV' means Wheelchair accessible vehicles. 'Taxi' means rider hails an actual taxi cab via Uber's app')</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>PRODUCT_ID</code></td>
#     <td style="text-align: left">service type ID (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>TIMES_STAMP</code></td>
#     <td style="text-align: left">epoch time when data was queried (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>SOURCE</code></td>
#     <td style="text-align: left">starting point of the ride (<strong>categorical</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>DESTINATION</code></td>
#     <td style="text-align: left">destination of the ride (<strong>categorical</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>PRICE</code></td>
#     <td style="text-align: left">price estimate for the ride, USD (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>SURGE_MULTIPLIER</code></td>
#     <td style="text-align: left">multiplier by which price was increased, default 1 (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>ID</code></td>
#     <td style="text-align: left">transaction ID (<strong>numeric</strong>)</td>
#   </tr>
# </table>

# %% [markdown]
# #### <u><span style=color:skyblue>**Weather</span> Data:**</u>

# %% [markdown]
# <table>
#   <tr>
#     <th style="text-align: left; background: lightgrey">Field Name</th>
#     <th style="text-align: left; background: lightgrey">Description</th>
#   <tr>
#     <td style="text-align: left"><code>TEMP</code></td>
#     <td style="text-align: left">temperature, fahrenheit (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>LOCATION</code></td>
#     <td style="text-align: left">location name (<strong>categorical</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>CLOUDS</code></td>
#     <td style="text-align: left">cloud cover, 'oktas' rep. eighths of the sky; e.g. 7 oktas = .875 = 7/8 oktas (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>PRESSURE</code></td>
#     <td style="text-align: left">air pressure, millibars, mb (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>RAIN</code></td>
#     <td style="text-align: left">inches, for the last hour (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>TIME_STAMP</code></td>
#     <td style="text-align: left">epoch time when row data was collected (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>HUMIDITY</code></td>
#     <td style="text-align: left">humidity % (<strong>numeric</strong>)</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><code>WIND</code></td>
#     <td style="text-align: left">wind speed, mph (<strong>numeric</strong>)</td>
#   </tr>
# </table>

# %% [markdown]
# #### <u>**Field of Interest:**</u>

# %% [markdown]
# <table>
#   <tr>
#     <th style="text-align: left; background: lightgrey">Field Name</th>
#     <th style="text-align: left; background: lightgrey">Description</th>
#   <tr>
#     <td style="text-align: left"><code>PRICE</code></td>
#     <td style="text-align: left">price estimate for the ride, USD (<strong>numeric</strong>)</td>
#   </tr>

# %% [markdown]
# #### <u>**Question of Interest:**</u> >??????IS THIS SECTION FULLY DONE YET?????????//
#
# Imagine Considering the all the variables that influence the price of cab rides in most cities, the following is to be evaluated: How do factors like weather, time of day, location, and cab type offering affect the price of a cab ride on the Uber & Lyft platforms?
#
# > 💡<u>Additional Questions to Consider:</u> Are there best practices or guidelines that all Uber & Lyft drivers can adhere to, regardless of their market, to increase efficiency in their drive times? Are there recommendations available that advise drivers, whether they're new to rideshare service or have experience, on how to make the most on their shifts?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cab_rides = pd.read_csv(r"C:\Users\garre\OneDrive\Documents\BrainStation\Capstone\Uber & Lyft Dataset\Uber & Lyft Dataset from Kaggle\Garrett's version of the data\USE THIS DATA FROM 11.24 AND ON\cab_rides.csv")
cab_rides.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name
# 0        Shared
# 1           Lux
# 2          Lyft
# ...

# %%
weather = pd.read_csv(r"C:\Users\garre\OneDrive\Documents\BrainStation\Capstone\Uber & Lyft Dataset\Uber & Lyft Dataset from Kaggle\Garrett's version of the data\USE THIS DATA FROM 11.24 AND ON\weather.csv")
weather.head()
# Out:
#     temp            location  clouds  pressure    rain  time_stamp  humidity  \
# 0  42.42            Back Bay     1.0   1012.14  0.1228  1545003901      0.77
# 1  42.43         Beacon Hill     1.0   1012.15  0.1846  1545003901      0.76
# 2  42.50   Boston University     1.0   1012.15  0.1089  1545003901      0.76
# 3  42.11              Fenway     1.0   1012.13  0.0969  1545003901      0.77
# 4  43.13  Financial District     1.0   1012.14  0.1786  1545003901      0.75
#
#     wind
# 0  11.25
# 1  11.32
# 2  11.07
# 3  11.09
# 4  11.49

# %% [markdown]
# # <u>#1 Data Cleaning & Exploratory Data Analysis (EDA)</u>

# %% [markdown]
# ---
#
# #### <span style=color:orange>**Cab_Rides**</span> dataset - .shape, .size, .info(), .column names, and dTypes

# %%
#shape and size 
print(f'The cab_rides dataset consists of {cab_rides.shape[0]} rows and {cab_rides.shape[1]} columns.')
print(f'The cab_rides dataset consists of {cab_rides.size} elements.')
# Out:
# The cab_rides dataset consists of 693071 rows and 11 columns.
# The cab_rides dataset consists of 7623781 elements.

# %%
#datatypes and nulls w/ df.info()
cab_rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Distance                  693071 non-null  float64
#  1   Cab_Type                  693071 non-null  object
#  2   Name                      693071 non-null  object
#  3   Product_ID                693071 non-null  object
#  4   Time_Stamp                693071 non-null  float64
#  5   Source / Pickup Location  693071 non-null  object
#  6   Destination               693071 non-null  object
#  7   Price                     637976 non-null  float64
#  8   Surge_Multiplier          693071 non-null  float64
#  9   ID                        693071 non-null  object
#  10  Unnamed: 10               1 non-null       float64
# dtypes: float64(5), object(6)
# memory usage: 58.2+ MB

# %%
#column names
cab_rides.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name'],
#       dtype='object')

# %%
#data types
cab_rides.dtypes
# Out:
# distance                   float64
# cab_type                    object
# time_stamp          datetime64[ns]
# destination                 object
# source                      object
# price                      float64
# surge_multiplier           float64
# id                          object
# product_id                  object
# name                        object
# dtype: object

# %%
#dataset description stats w/ .describe()
cab_rides.describe()
# Out:
#             distance                     time_stamp          price  \
# count  693071.000000                         693071  637976.000000
# mean        2.189430  2018-12-05 21:35:09.764357120      16.545125
# min         0.020000     2018-11-26 03:40:46.318000       2.500000
# 25%         1.280000  2018-11-28 22:26:08.356499968       9.000000
# 50%         2.160000  2018-12-02 07:57:57.528999936      13.500000
# 75%         2.920000  2018-12-14 22:45:08.976499968      22.500000
# max         7.860000     2018-12-18 19:15:10.943000      97.500000
# std         1.138937                            NaN       9.324359
#
#        surge_multiplier
# count     693071.000000
# mean           1.013870
# min            1.000000
# 25%            1.000000
# 50%            1.000000
# 75%            1.000000
# max            3.000000
# std            0.091641

# %%
#dataset description stats transposed w/ .describe().T
cab_rides.describe().T
# Out:
#                      count                           mean  \
# distance          693071.0                        2.18943
# time_stamp          693071  2018-12-05 21:35:09.764357120
# price             637976.0                      16.545125
# surge_multiplier  693071.0                        1.01387
#
#                                          min                            25%  \
# distance                                0.02                           1.28
# time_stamp        2018-11-26 03:40:46.318000  2018-11-28 22:26:08.356499968
# price                                    2.5                            9.0
# surge_multiplier                         1.0                            1.0
#
#                                             50%  \
# distance                                   2.16
# time_stamp        2018-12-02 07:57:57.528999936
# price                                      13.5
# surge_multiplier                            1.0
#
# ...

# %% [markdown]
# ---
#
# #### <span style=color:skyblue>**Weather**</span> dataset - .shape, .size, .info(), .column names, and dTypes

# %%
#Looking at shape and size 
print(f'The weather dataset consists of {weather.shape[0]} rows and {weather.shape[1]} columns.')
print(f'The weather dataset consists of {weather.size} elements.')
# Out:
# The weather dataset consists of 6276 rows and 8 columns.
# The weather dataset consists of 50208 elements.

# %%
#datatypes and nulls w/ df.info()
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6276 entries, 0 to 6275
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Temp        6276 non-null   float64
#  1   Location    6276 non-null   object
#  2   Clouds      6276 non-null   float64
#  3   Pressure    6276 non-null   float64
#  4   Rain        894 non-null    float64
#  5   Time_Stamp  6276 non-null   int64
#  6   Humidity    6276 non-null   float64
#  7   Wind        6276 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 392.4+ KB

# %%
#column names
weather.columns
# Out:
# Index(['Temp', 'Location', 'Clouds', 'Pressure', 'Rain', 'Time_Stamp',
#        'Humidity', 'Wind'],
#       dtype='object')

# %%
#data types
weather.dtypes
# Out:
# Temp          float64
# Location       object
# Clouds        float64
# Pressure      float64
# Rain          float64
# Time_Stamp      int64
# Humidity      float64
# Wind          float64
# dtype: object

# %%
#dataset description stats w/ .describe()
weather.describe()
# Out:
#               Temp       Clouds     Pressure        Rain    Time_Stamp  \
# count  6276.000000  6276.000000  6276.000000  894.000000  6.276000e+03
# mean     39.090475     0.677777  1008.445209    0.057652  1.543857e+09
# std       6.022055     0.314284    12.870775    0.100758  6.659340e+05
# min      19.620000     0.000000   988.250000    0.000200  1.543204e+09
# 25%      36.077500     0.440000   997.747500    0.004900  1.543387e+09
# 50%      40.130000     0.780000  1007.660000    0.014850  1.543514e+09
# 75%      42.832500     0.970000  1018.480000    0.060925  1.544691e+09
# max      55.410000     1.000000  1035.120000    0.780700  1.545159e+09
#
#           Humidity         Wind
# count  6276.000000  6276.000000
# mean      0.763985     6.802812
# std       0.127340     3.633466
# min       0.450000     0.290000
# 25%       0.670000     3.517500
# 50%       0.760000     6.570000
# 75%       0.890000     9.920000
# max       0.990000    18.180000

# %%
#dataset description stats w/ .describe().T
weather.describe().T
# Out:
#              count          mean            std           min           25%  \
# Temp        6276.0  3.909047e+01       6.022055  1.962000e+01  3.607750e+01
# Clouds      6276.0  6.777772e-01       0.314284  0.000000e+00  4.400000e-01
# Pressure    6276.0  1.008445e+03      12.870775  9.882500e+02  9.977475e+02
# Rain         894.0  5.765235e-02       0.100758  2.000000e-04  4.900000e-03
# Time_Stamp  6276.0  1.543857e+09  665933.983457  1.543204e+09  1.543387e+09
# Humidity    6276.0  7.639850e-01       0.127340  4.500000e-01  6.700000e-01
# Wind        6276.0  6.802812e+00       3.633466  2.900000e-01  3.517500e+00
#
#                      50%           75%           max
# Temp        4.013000e+01  4.283250e+01  5.541000e+01
# Clouds      7.800000e-01  9.700000e-01  1.000000e+00
# Pressure    1.007660e+03  1.018480e+03  1.035120e+03
# Rain        1.485000e-02  6.092500e-02  7.807000e-01
# Time_Stamp  1.543514e+09  1.544691e+09  1.545159e+09
# ...

# %% [markdown]
# ---
#
# ### Exploratory Data Analysis (EDA) cont.
# - Distribution of data (*<span style=color:orange>**Cab_Rides**</span> & <span style=color:skyblue>**Weather**</span>*)
# - Check for duplicated Rows
# - Check for null values

# %% [markdown]
# #### Distributions of <span style=color:orange>**Cab_Rides**</span> data

# %%
#distribution count between Uber and Lyft rides
#count the values w/ .value_counts() and plot
ax = cab_rides['Cab_Type'].value_counts().plot(kind='bar', color=['black', (0.5, 0.2, 0.7)])

ax.set_title('Distribution of Cab Types')
ax.set_xlabel('Cab Type')
ax.set_ylabel('Count')
plt.show()

#print distribution count
print(cab_rides['Cab_Type'].value_counts())
# Out:
# Cab_Type
# Uber    385663
# Lyft    307408
# Name: count, dtype: int64

# %%
#count occurrences of each ride type by `cab_type`
counts = cab_rides.groupby(['Cab_Type', 'Name']).size().unstack(fill_value=0)

#create bar plot
plt.figure(figsize=(10, 6))

#create bars for each `cab_type`
counts.plot(kind='bar', width=0.8, color=['blue' if 'Uber' in name else 'purple' for name in counts.columns])

plt.xticks(rotation=45, ha='right')
plt.ylabel('Count')
plt.title('Counts of Ride Type by App')

#display legend to the side
plt.legend(title='Ride Type', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
bar_colors = ['black', (0.5, 0.2, 0.7)]

cab_rides['Name'].value_counts().plot(kind='bar', color=['black' if 'Uber' in name else 'purple' for name in counts.columns])
# Out:
# <Axes: xlabel='Name'>

# %%
#.apply(lambda x) used to identify/confirm the strings in the Product_ID column are actually 36 characters confirming they are UUID numbers
#UUID numbers are a transaction ID for each ride  
cab_rides['Product_Type'] = cab_rides['Product_ID'].apply(lambda x: 'UUID' if len(x) == 36 and x.count('-') == 4 else x)

#count the occurrences of each type with 'Product_Type' varible
print(cab_rides['Product_Type'].value_counts())
# Out:
# Product_Type
# UUID            385663
# lyft_premier     51235
# lyft             51235
# lyft_luxsuv      51235
# lyft_plus        51235
# lyft_lux         51235
# lyft_line        51233
# Name: count, dtype: int64

# %%
plt.subplots(4, 5, figsize=(15, 10))

count = 1

for col in cab_rides.columns:
    plt.subplot(4, 5, count)
    plt.hist(cab_rides[col])
    plt.title(col)
    
    count += 1
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 12
#       8     plt.title(col)
#      10     count += 1
# ---> 12 plt.show()
#
# File c:\Users\garre\anaconda3\envs\base_env\Lib\site-packages\matplotlib\pyplot.py:612, in show(*args, **kwargs)
#     568 """
#     569 Display all open figures.
#     570
#    (...)
#     609 explicitly there.
#     610 """
#     611 _warn_if_gui_out_of_main_thread()
# --> 612 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\garre\anaconda3\envs\base_env\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
# ...

# %%
#There are 385,663 rows in Product_ID column with a random UUID column.
#Standard UUIDs are 36 characters long including hyphens.

print(cab_rides['Product_ID'].unique())
# Out:
# ['lyft_line' 'lyft_premier' 'lyft' 'lyft_luxsuv' 'lyft_plus' 'lyft_lux'
#  '6f72dfc5-27f1-42e8-84db-ccc7a75f6969'
#  '6c84fd89-3f11-4782-9b50-97c468b19529'
#  '55c66225-fbe7-4fd5-9072-eab1ece5e23e'
#  '9a0e7b09-b92b-4c41-9779-2ad22b4d779d'
#  '6d318bcc-22a3-4af6-bddd-b409bfce1546'
#  '997acbb5-e102-41e1-b155-9df7de0a73f2'
#  '8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a']

# %%
# space left to decide on `UUID` or `Unknown` for `Product_ID` column ^^^

# %% [markdown]
# #### Distributions of <span style=color:skyblue>**Weather**</span> data

# %%
#distribution of temperature
plt.figure(figsize=(10, 6))
#histogram
weather['Temp'].plot(kind='hist', bins=25, color='Gold', alpha=0.7)

#frequency showing number of Uber/Lyft rides completed at given `temp`
plt.title('Distribution of Temperature (°F)')
plt.xlabel('Temperature (°F)')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#distribution of `rain`
plt.figure(figsize=(10, 6))
#histogram
weather['Rain'].plot(kind='hist', bins=20, color='skyblue', alpha=0.7)

#frequency showing number of Uber/Lyft rides completed given `rain`fall
plt.title('Distribution of Rain (°F)')
plt.xlabel('Rain (inches)')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#distribution of wind
plt.figure(figsize=(10, 6))
#histogram
weather['Wind'].plot(kind='hist', bins=20, color='lightgray', alpha=0.7)

#frequency showing number of Uber/Lyft rides completed given wind speed
plt.title('Distribution of Wind')
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#subplots showing same distributions of `wind`, `temp`, and `rain`
#list of columns and their corresponding titles and colors
columns = ['Wind', 'Temp', 'Rain']
titles = ['Distribution of Wind', 'Distribution of Temperature', 'Distribution of Rain']
colors = ['lightgray', 'gold', 'skyblue']

#create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

#loop through columns, titles, colors
for ax, col, title, color in zip(axes, columns, titles, colors):
    ax.hist(weather[col], bins=20, color=color, alpha=0.7)
    ax.set_title(title)
    ax.set_xlabel(f'{col} Value')
    ax.set_ylabel('Frequency')
    ax.grid(True, alpha=0.6)

plt.tight_layout()
plt.show()

# %%
<s>#plt.subplots(4, 5, figsize=(15, 10))

count = 1

for col in cab_rides.columns:
    plt.subplot(4, 5, count)
    plt.hist(cab_rides[col])
    plt.title(col)
    
    count += 1
    
plt.show()</s>
# Out:
#   Cell In[44], line 1
#     <s>#plt.subplots(4, 5, figsize=(15, 10))
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Converting `time_stamp` column for both <span style=color:orange>**Cab_Rides**</span> and <span style=color:skyblue>**Weather**</span> datasets

# %%
#converting time_stamp column for cab_data and weather dataset
#time_stamp column measures to milliseconds, conversion unit = `ms`
cab_rides['time_stamp'] = pd.to_datetime(cab_rides['time_stamp'], unit='ms')
weather['time_stamp'] = pd.to_datetime(weather['time_stamp'], unit='ms')
print(cab_rides['time_stamp'].head())
print(weather['time_stamp'].head())
# Out:
# 0   2018-12-16 09:30:07.890
# 1   2018-11-27 02:00:23.677
# 2   2018-11-28 01:00:22.198
# 3   2018-11-30 04:53:02.749
# 4   2018-11-29 03:49:20.223
# Name: time_stamp, dtype: datetime64[ns]
# 0   1970-01-18 21:10:03.901
# 1   1970-01-18 21:10:03.901
# 2   1970-01-18 21:10:03.901
# 3   1970-01-18 21:10:03.901
# 4   1970-01-18 21:10:03.901
# Name: time_stamp, dtype: datetime64[ns]

# %% [markdown]
# #### Look for duplicated rows in <span style=color:orange>**Cab_Rides**</span> dataset

# %%
#look for duplicate rows w/ .duplicated()
cab_rides.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 693066    False
# 693067    False
# 693068    False
# 693069    False
# 693070    False
# Length: 693071, dtype: bool

# %%
#sanity check
duplicate_count = cab_rides.duplicated().sum()
print(duplicate_count)
#no duplicates found
# Out:
# 0

# %% [markdown]
# #### Look for duplicated rows in <span style=color:SkyBlue>**Weather**</span> dataset

# %%
#look for duplicate rows w/ .duplicated()
weather.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6271    False
# 6272    False
# 6273    False
# 6274    False
# 6275    False
# Length: 6276, dtype: bool

# %%
#sanity check
duplicate_count2 = weather.duplicated().sum()
print(duplicate_count2)
#no duplicates found
# Out:
# 0

# %% [markdown]
# #### Look for null values in <span style=color:orange>**Cab_Rides**</span> dataset

# %%
#look at the number of nulls for each column in cab_rides dataset
cab_rides.isna().sum()
#it can be seen `price` column has 55,095 null values.
# Out:
# Distance                         0
# Cab_Type                         0
# Name                             0
# Product_ID                       0
# Time_Stamp                       0
# Source / Pickup Location         0
# Destination                      0
# Price                        55095
# Surge_Multiplier                 0
# ID                               0
# Unnamed: 10                 693070
# dtype: int64

# %% [markdown]
# # can I copy the same code from changing rain values into zeros but for the Price column? is that ok? see the cell below  vvv

# %%
#null/missing values for `price` column seen in previous cells are replaced with zeros
cab_rides['Price'] = cab_rides['Price'].fillna(0.00)
print(cab_rides['Price'].head())

# %% [markdown]
# #### Look for null values in <span style=color:skyblue>**Weather**</span> dataset

# %%
#look for number of nulls
weather.isna().sum()
#`rain` column has 5,382 null values
# Out:
# Temp             0
# Location         0
# Clouds           0
# Pressure         0
# Rain          5382
# Time_Stamp       0
# Humidity         0
# Wind             0
# dtype: int64

# %%
#null/missing values for `rain` column seen in previous cell are replaced with zeros 
weather['Rain'] = weather['Rain'].fillna(0.00)
print(weather['Rain'].head())
# Out:
# 0    0.1228
# 1    0.1846
# 2    0.1089
# 3    0.0969
# 4    0.1786
# Name: Rain, dtype: float64

# %%
#sanity check
weather.isna().sum()
#no more null/missing values for `rain` column
# Out:
# Temp          0
# Location      0
# Clouds        0
# Pressure      0
# Rain          0
# Time_Stamp    0
# Humidity      0
# Wind          0
# dtype: int64

# %% [markdown]
# ---
#
# ### Exploratory Data Analysis (EDA) cont.
#
# `Map` distributions of the Numerical columns.
#
# The Numerical columns for <span style=color:orange>**Cab_Rides**</span> dataset are:
#
# <ul>
#   <li>Distance</li>
#   <li>Time_Stamp</li>
#   <li>Price</li>
#   <li>Surge_Multiplier</li>
# </ul>

# %%
#distribution of `distance`
plt.figure(figsize=(10, 6))
#histogram
cab_rides['Distance'].plot(kind='hist', bins=30, color='IndianRed', alpha=0.7)

#frequency showing number of Uber/Lyft rides completed given the recorded trip `distance`
plt.title('Distribution of Distance')
plt.xlabel('Distance (miles)')
plt.ylabel('Occurrences Observed')
plt.grid(True, alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#distribution of `price`
plt.figure(figsize=(10, 6))
#histogram
cab_rides['Price'].plot(kind='hist', bins=30, color='MediumSeaGreen', alpha=0.7)

#frequency showing number of Uber/Lyft rides completed given the recorded trip `price`
plt.title('Distribution of Price')
plt.xlabel('Price (USD)')
plt.ylabel('Occurrences Observed')
plt.grid(True, alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#distribution of `surge_multiplier`
plt.figure(figsize=(10, 6))
#histogram
cab_rides['Surge_Multiplier'].plot(kind='hist', bins=30, color='RebeccaPurple', alpha=0.7)

#frequency showing number of Uber/Lyft rides completed at each `surge_multiplier` increment
#i.e., multiplier by which price was increased
plt.title('Distribution of Surge Multiplier')
plt.xlabel('Surge Multiplier, default=1')
plt.ylabel('Occurrences Observed')
plt.grid(True, alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exploratory Data Analysis (EDA) cont.
#
#
# `Map` the distribution of other <span style=color:skyblue>**Weather**</span> columns.
#
# Other <span style=color:skyblue>**Weather**</span> columns (numerical) for  dataset are:
#
# <ul>
#   <li>Clouds</li>
#   <li>Air Pressure</li>
#   <li>Humidity</li>
# </ul>

# %%
#distribution of air `pressure`
plt.figure(figsize=(10, 6))
#histogram
weather['Clouds'].plot(kind='hist', bins=30, color='Gray', alpha=0.7)

#frequency showing number of Uber/Lyft rides completed given the `air pressure`
plt.title('Distribution of Clouds')
plt.xlabel('Cloud Coverage (% of sky)')
plt.ylabel('Occurrences Observed')
plt.grid(True, alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#distribution of air `pressure`
plt.figure(figsize=(10, 6))
#histogram
weather['Pressure'].plot(kind='hist', bins=20, color='DarkSalmon', alpha=0.7)

#frequency showing number of Uber/Lyft rides completed given the `air pressure`
plt.title('Distribution of Air Pressure')
plt.xlabel('Air Pressure (mb)')
plt.ylabel('Occurrences Observed')
plt.grid(True, alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#distribution of `humidity`
plt.figure(figsize=(10, 6))
#histogram
weather['Humidity'].plot(kind='hist', bins=20, color='DarkTurquoise', alpha=0.7)

#frequency showing number of Uber/Lyft rides completed given the `humidity`
plt.title('Distribution of Humidity')
plt.xlabel('Humidity (%)')
plt.ylabel('Occurrences Observed')
plt.grid(True, alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#subplots showing same distributions of `clouds`, `pressure`, and `humidity`
#list of columns and their corresponding titles and colors
columns = ['Clouds', 'Pressure', 'Humidity']
titles = ['Distribution of Clouds', 'Distribution of Air Pressure', 'Distribution of Humidity']
colors = ['Gray', 'DarkSalmon', 'DarkTurquoise']

#create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

#loop through columns, titles, colors
for ax, col, title, color in zip(axes, columns, titles, colors):
    ax.hist(weather[col], bins=20, color=color, alpha=0.7)
    ax.set_title(title)
    ax.set_xlabel(f'{col} Value')
    ax.set_ylabel('Frequency')
    ax.grid(True, alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exploratory Data Analysis (EDA) cont.
#
# From <span style=color:orange>**Cab_Rides**</span> dataset, find relationship between <u>number of rides completed</u> and time of day (by **`week`**).

# %%
cab_rides['Time_Stamp'].describe()
# Out:
# count                           693071
# mean     2018-11-03 10:54:30.107680256
# min                2018-10-20 01:46:40
# 25%                2018-10-20 01:46:40
# 50%                2018-10-20 01:46:40
# 75%                2018-10-20 01:46:40
# max                2019-02-12 19:33:20
# Name: Time_Stamp, dtype: object

# %%
#`time_stamp` columns has been previously converted to datetime
#cab_rides['time_stamp'] = pd.to_datetime(cab_rides['time_stamp'], unit='ms')

# %%
#extract the week and the date
cab_rides['week_start'] = cab_rides['time_stamp'].dt.to_period('W').dt.start_time

# %%
#count the number of rides in each week w/ .groupby() and .size()
weekly_rides = cab_rides.groupby('week_start').size()

# %%
cab_rides['week_start'].value_counts()
# Out:
# week_start
# 2018-11-26    376625
# 2018-12-10    176088
# 2018-12-17     81120
# 2018-12-03     59238
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
weekly_rides.plot(kind='bar', color='lightgreen')
plt.title('Weekly Cab Rides')
plt.xlabel('Week')
plt.ylabel('Number of Rides')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exploratory Data Analysis (EDA) cont.
#
# From <span style=color:orange>**Cab_Rides**</span> dataset, find relationship between `distance` of completed rides and the `surge_multiplier` applied to the ride.

# %% [markdown]
# Find relationship between Distance and Surged Multiplier

# %%
#create a scatter plot to show relationship between 'Distance' and 'Surge_Multiplier'
plt.figure(figsize=(10, 6))
plt.scatter(cab_rides['Distance'], cab_rides['Surge_Multiplier'], color='blue', alpha=0.1, edgecolors='w', linewidth=0.5)
plt.xlabel('Distance (miles)')
plt.ylabel('Surge Multiplier')
plt.title('Relationship between Distance and Surge Multiplier')
plt.tight_layout()
plt.show()

# %% [markdown]
# DO I STILL WANT/NEED TO DO THIS ? ⬇️ Plotting distribution of categorical columns?

# %% [markdown]
# Visualize the data - cont.
#
#
# `Plot` the distribution of Categorical columns.
#
# The <u>Categorical</u> columns for `cab_rides` dataset are as follows:
#
# <ul>
#   <li>Cab_Type</li>
#   <li>Name</li>
#   <li>Product_ID</li>
#   <li>Source / Pickup Location</li>
#   <li>Destination</li>
#   <li>ID</li>
# </ul>

# %%
def can_see_stage(seats):
    # Transpose the seats matrix to check each column
    transposed = list(zip(*seats))
    
    # Check each column
    for column in transposed:
        for i in range(1, len(column)):
            if column[i] <= column[i - 1]:
                return False
    return True

# Example usage
seats = [
    [1, 2, 3, 2, 1, 1],
    [2, 4, 4, 3, 2, 2],
    [5, 5, 5, 5, 4, 4],
    [6, 6, 7, 6, 5, 5]
]

print(can_see_stage(seats))  # Output: False
# Out:
# True

# %% [markdown]
# ---
#
# ### Time Series Analysis
# - write out some high levl steps here in bullet points

# %%
cab_rides = cab_rides.set_index('time_stamp', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 cab_rides = cab_rides.set_index('time_stamp')
#
# AttributeError: 'NoneType' object has no attribute 'set_index'

# %%
cab_rides['time_stamp']

# %%
# decompose the time series
decomposition = tsa.seasonal_decompose(cab_rides, model='additive')


from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(cab_rides['Surge_Multiplier'], model='additive', period=24)
result.plot()

# %%
cab_rides['Surge_Multiplier'].plot(figsize=(10, 6))
plt.title("Surge Multiplier Trend")
plt.xlabel("Date")
plt.ylabel("Surge Multiplier")
plt.show()

# %%
air_traffic_monthly["Trend"] = decomposition.trend

# %%
cols = ["Trend", "Seasonal", "Residual"]

fig = make_subplots(rows=3, cols=1, subplot_titles=cols)

for i, col in enumerate(cols):
    fig.add_trace(
        go.Scatter(x=air_traffic_monthly.index, y=air_traffic_monthly[col]),
        row=i+1,
        col=1
    )

fig.update_layout(height=800, width=1200, showlegend=False)
fig.show()
